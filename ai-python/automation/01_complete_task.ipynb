# %%
import sys
sys.path.append('..')
from helper_functions import print_llm_response, get_llm_response

# %%
name = "Daniel"

# %%
prompt = f"""
Write a four line birthday poem for my friend {name}. 
The poem should be inspired by the first letter of my friend's name.
"""
print_llm_response(prompt)
# Out:
# Dashing Daniel, dear and true,
# Dancing through life with zest anew.
# Dreams and laughter fill your day,
# Delight in every step of your way.

# %% [markdown]
# ## Creating  a list

# %%
friends_list = ["Tommy", "Sarah", "John", "Alice", "Bob"]

# %%
print(friends_list)
# Out:
# ['Tommy', 'Sarah', 'John', 'Alice', 'Bob']

# %%
prompt = f"""
Write a set of four line birthday poems for my friends {friends_list}. 
The poems should be inspired by the first letter of each friend's name.
"""
print(prompt)
# Out:
# Write a set of four line birthday poems for my friends ['Tommy', 'Sarah', 'John', 'Alice', 'Bob'].
# The poems should be inspired by the first letter of each friend's name.

# %%
print_llm_response(prompt)
# Out:
# 1. Tommy, you shine bright like a star,
# On your birthday, may you go far.
# May joy and laughter fill your day,
# Happy birthday in every way!
#
# 2. Sarah, a friend so kind and true,
# On your special day, we celebrate you.
# May happiness and love surround,
# In joy and laughter, may you abound!
#
# 3. John, a friend so loyal and dear,
# On your birthday, let's raise a cheer.
# May your day be filled with delight,
# Wishing you happiness, morning to night!
#
# 4. Alice, with a heart so pure and kind,
# On your birthday, may joy find
# Its way to you in every way,
# Happy birthday, have a wonderful day!
#
# 5. Bob, a friend so full of cheer,
# On your birthday, let's make it clear.
# You're special in every way,
# Wishing you a fantastic day!

# %% [markdown]
# ## Lists with other data types

# %%
list_ages = [42, 28, 30]

# %%
print(list_ages)
# Out:
# [42, 28, 30]

# %% [markdown]
# Lists can also hold long strings. Here's a list of tasks that might make up a todo list

# %%
#list of tasks in priority order. Multi-line lists are allowed in python!
list_of_tasks = [
    "Compose a brief email to my boss explaining that I will be late for tomorrow's meeting.",
    "Write a birthday poem for Otto, celebrating his 28th birthday.",
    "Write a 300-word review of the movie 'The Arrival'."
]

# %%
task = list_of_tasks[0]
print_llm_response(task)
# Out:
# Subject: Running Late for Tomorrow's Meeting
#
# Hi [Boss's Name],
#
# I wanted to let you know that I will be running a few minutes late for tomorrow's meeting. I apologize for any inconvenience this may cause.
#
# Thank you for your understanding.
#
# Best,
# [Your Name]

# %%
task = list_of_tasks[1]
print_llm_response(task)
# Out:
# Happy 28th birthday, Otto dear,
# Another year to hold so near.
# May joy and laughter fill your day,
# And blessings come in every way.
#
# With each year that passes by,
# May your dreams reach for the sky.
# Celebrate this special date,
# And let happiness be your fate.
#
# So blow out the candles, make a wish,
# For a year ahead filled with bliss.
# Happy birthday, Otto, may it be great,
# Enjoy every moment, celebrate!

# %%
task = list_of_tasks[2]
print_llm_response(task)
# Out:
# "The Arrival" is a captivating science fiction film that delves into the complexities of communication and the consequences of human actions. Directed by Denis Villeneuve, the movie follows linguistics professor Louise Banks, played brilliantly by Amy Adams, as she is tasked with deciphering the language of extraterrestrial visitors who have arrived on Earth.
#
# The film's slow-burning tension and thought-provoking narrative keep viewers on the edge of their seats as Louise navigates the challenges of decoding an alien language while grappling with personal grief. Adams delivers a powerful and nuanced performance, capturing the emotional depth of her character's journey.
#
# Visually stunning and expertly crafted, "The Arrival" immerses audiences in a world that feels both familiar and otherworldly. The alien spacecraft and their intricate language are brought to life with stunning visual effects that enhance the film's sense of wonder and mystery.
#
# The film's exploration of time, memory, and the nature of communication adds layers of depth to the story, inviting viewers to ponder the complexities of human existence and the ways in which we connect with others.
#
# While some may find the film's slow pace and cerebral themes challenging, those who appreciate thoughtful science fiction will be rewarded with a rich and rewarding viewing experience. "The Arrival" is a masterful blend of intellect and emotion, offering a unique and compelling take on the alien invasion genre.
#
# In conclusion, "The Arrival" is a must-see film for fans of science fiction and thought-provoking cinema. With its stellar performances, stunning visuals, and profound themes, it is a standout entry in the genre that will leave a lasting impact on viewers.

# %% [markdown]
# ## Extra practice

# %%
# Create a list with the titles 
# of five of your favorite movies

movie_list = ["Inception", "The Matrix", "Interstellar", "The Dark Knight", "Pulp Fiction"]

# %%
# Display the fourth element of 
# the following list using print()

prime_numbers = [2, 3, 5, 7, 11]
print(prime_numbers[3])
# Out:
# 7

# %%
# Add one name to friends_list using append

friends_list = ["Tommy", "Isabel", "Daniel", "Otto"]
friends_list.append("Luna")

print(friends_list)
# Out:
# ['Tommy', 'Isabel', 'Daniel', 'Otto', 'Luna']

# %%
# In the following code, remove the country 
# that is not in South America

countries_in_south_america = ["Colombia", "Peru", 
                              "Brasil", "Japan",
                              "Argentina"]

countries_in_south_america.remove("Japan")

print(countries_in_south_america)
# Out:
# ['Colombia', 'Peru', 'Brasil', 'Argentina']
