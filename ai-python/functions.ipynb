# %%
from helper_functions import print_llm_response

# %%
print_llm_response("Tell me a joke")
# Out:
# Why couldn't the bicycle stand up by itself? It was two tired.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, Otto Matic would be considered an adult dog. This life stage typically entails high energy levels, a strong interest in play and exercise, and a need for mental stimulation. Adult dogs may exhibit behaviors such as increased independence, established routines, and continued learning and training opportunities to keep them engaged and happy.

# %%
driver = "unicorn"
drivers_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {drivers_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# Once upon a time in a magical land far, far away, there was a unicorn named Sparkle and a colorful, asymmetric dinosaur car named Roary. They were both determined to win the prestigious Pluto Champion Cup, the most thrilling and challenging race in the entire universe.
#
# Sparkle, with her shimmering white coat and rainbow-colored mane, was known for her speed and agility. Roary, with his bright green scales and mismatched wheels, was famous for his daring maneuvers and lightning-fast acceleration.
#
# As the race day approached, excitement filled the air. The spectators gathered at the starting line, eagerly awaiting the epic showdown between Sparkle and Roary. The race track was filled with twists and turns, loops and jumps, presenting a formidable challenge for both competitors.
#
# The race began, and Sparkle and Roary raced neck and neck, each determined to outdo the other. Sparkle's hooves pounded the ground as she galloped with grace and elegance, while Roary's wheels spun furiously as he zigzagged through the obstacles with precision and skill.
#
# As they approached the finish line, the crowd held their breath in anticipation. In a final burst of speed, Sparkle surged ahead, crossing the finish line just a split second before Roary. The crowd erupted into cheers and applause as Sparkle was crowned the winner of the Pluto Champion Cup.
#
# Despite the fierce competition, Sparkle and Roary embraced each other in a show of sportsmanship and friendship. They may have been rivals on the race track, but they knew that true champions always respect and support each other.
#
# And so, Sparkle and Roary became legends in the racing world, inspiring others to chase their dreams and never give up, no matter how challenging the race may be.
